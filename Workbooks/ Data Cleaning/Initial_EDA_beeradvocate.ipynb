# %%
# Designating one cell for all imports

import pandas as pd

# %%
# !ls
# Out:
# Initial_EDA_beeradvocate.ipynb

# %%
df_ba = pd.read_csv('../../data/beer_reviews.csv')


#df_ba stands for initial beer advocate data

# %%
df_ba.head()
# Out:
#    brewery_id             brewery_name  review_time  review_overall  \
# 0       10325          Vecchio Birraio   1234817823             1.5
# 1       10325          Vecchio Birraio   1235915097             3.0
# 2       10325          Vecchio Birraio   1235916604             3.0
# 3       10325          Vecchio Birraio   1234725145             3.0
# 4        1075  Caldera Brewing Company   1293735206             4.0
#
#    review_aroma  review_appearance review_profilename  \
# 0           2.0                2.5            stcules
# 1           2.5                3.0            stcules
# 2           2.5                3.0            stcules
# 3           3.0                3.5            stcules
# 4           4.5                4.0     johnmichaelsen
#
#                        beer_style  review_palate  review_taste  \
# 0                      Hefeweizen            1.5           1.5
# 1              English Strong Ale            3.0           3.0
# ...

# %%
df_ba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1586614 entries, 0 to 1586613
# Data columns (total 13 columns):
#  #   Column              Non-Null Count    Dtype
# ---  ------              --------------    -----
#  0   brewery_id          1586614 non-null  int64
#  1   brewery_name        1586599 non-null  object
#  2   review_time         1586614 non-null  int64
#  3   review_overall      1586614 non-null  float64
#  4   review_aroma        1586614 non-null  float64
#  5   review_appearance   1586614 non-null  float64
#  6   review_profilename  1586266 non-null  object
#  7   beer_style          1586614 non-null  object
#  8   review_palate       1586614 non-null  float64
#  9   review_taste        1586614 non-null  float64
#  10  beer_name           1586614 non-null  object
#  11  beer_abv            1518829 non-null  float64
#  12  beer_beerid         1586614 non-null  int64
# dtypes: float64(6), int64(3), object(4)
# memory usage: 157.4+ MB

# %%
df_ba.isna().sum()
# Out:
# brewery_id                0
# brewery_name             15
# review_time               0
# review_overall            0
# review_aroma              0
# review_appearance         0
# review_profilename      348
# beer_style                0
# review_palate             0
# review_taste              0
# beer_name                 0
# beer_abv              67785
# beer_beerid               0
# dtype: int64

# %% [markdown]
# Looks like we have some missing values to deal with:
#
# 1. 15 in brewery_name
# 2. 348 in review_profilename
# 3. ~67k in beer_abv

# %% [markdown]
# ## Dealing with brewery_name

# %%
df_ba[df_ba['brewery_name'].isna()]
# Out:
#          brewery_id brewery_name  review_time  review_overall  review_aroma  \
# 651565         1193          NaN   1301022066             2.0           2.5
# 659293         1193          NaN   1290107698             4.0           4.5
# 659299         1193          NaN   1289077001             3.5           3.0
# 659300         1193          NaN   1289851033             3.5           4.0
# 659301         1193          NaN   1289158632             3.5           4.0
# 659302         1193          NaN   1289590065             3.5           4.0
# 659303         1193          NaN   1298078926             3.0           3.0
# 659304         1193          NaN   1292423271             4.5           4.0
# 659305         1193          NaN   1289329962             3.5           3.5
# 1391043          27          NaN   1020244856             3.5           3.5
# 1391049          27          NaN   1143182956             2.5           2.0
# ...

# %% [markdown]
# Just looks like we're missing brewery_name for brewery_id that represent 1193 and 27. Let's take a look to see if we have values for these in other data entries.

# %%
df_ba[df_ba['brewery_id'] == 1193]
# Out:
#         brewery_id brewery_name  review_time  review_overall  review_aroma  \
# 651565        1193          NaN   1301022066             2.0           2.5
# 659293        1193          NaN   1290107698             4.0           4.5
# 659299        1193          NaN   1289077001             3.5           3.0
# 659300        1193          NaN   1289851033             3.5           4.0
# 659301        1193          NaN   1289158632             3.5           4.0
# 659302        1193          NaN   1289590065             3.5           4.0
# 659303        1193          NaN   1298078926             3.0           3.0
# 659304        1193          NaN   1292423271             4.5           4.0
# 659305        1193          NaN   1289329962             3.5           3.5
#
#         review_appearance review_profilename                  beer_style  \
# 651565                2.5            Knapp85                Vienna Lager
# ...

# %% [markdown]
# Doesn't look like we have any brewery_id here however it's clean from the name of the beers and a little google search later, the brewery in this case is Engel located in Crailshaim, Germany.

# %%
df_ba.loc[df_ba['brewery_id'] == 1193, ['brewery_name']] = 'Engel' 

# Now let's check that worked to replace our brewery name

# %%
df_ba[df_ba['brewery_id'] == 1193]

# Looks like that worked, let's check out the other value
# Out:
#         brewery_id brewery_name  review_time  review_overall  review_aroma  \
# 651565        1193        Engel   1301022066             2.0           2.5
# 659293        1193        Engel   1290107698             4.0           4.5
# 659299        1193        Engel   1289077001             3.5           3.0
# 659300        1193        Engel   1289851033             3.5           4.0
# 659301        1193        Engel   1289158632             3.5           4.0
# 659302        1193        Engel   1289590065             3.5           4.0
# 659303        1193        Engel   1298078926             3.0           3.0
# 659304        1193        Engel   1292423271             4.5           4.0
# 659305        1193        Engel   1289329962             3.5           3.5
#
#         review_appearance review_profilename                  beer_style  \
# 651565                2.5            Knapp85                Vienna Lager
# ...

# %%
df_ba[df_ba['brewery_id'] == 27]
# Out:
#          brewery_id brewery_name  review_time  review_overall  review_aroma  \
# 1391043          27          NaN   1020244856             3.5           3.5
# 1391049          27          NaN   1143182956             2.5           2.0
# 1391050          27          NaN   1117963232             1.5           1.5
# 1391051          27          NaN   1323314674             4.5           4.5
# 1391052          27          NaN   1320989774             3.5           4.0
# 1391053          27          NaN   1320995408             5.0           4.5
#
#          review_appearance review_profilename              beer_style  \
# 1391043                3.5              Jason  American Adjunct Lager
# 1391049                2.0            BeerBob    American Malt Liquor
# 1391050                2.0      feloniousmonk    American Malt Liquor
# 1391051                3.5             ccrida            American IPA
# 1391052                3.5              Docer            American IPA
# ...

# %% [markdown]
# Similar story for brewery_id 27, doesn't look like this value exists at all within our dataframe. Let's try a similar technique by looking at the beer names to see if a brewery can be determined.

# %%
# American Brewing Company

# %%
df_ba.loc[df_ba['brewery_id'] == 27, ['brewery_name']] = 'American Brewing Company'

# %%
df_ba['brewery_name'].isna().sum()
# Out:
# 0

# %% [markdown]
# Nice, we've now dealt with all values in the brewery_name columns. Let's tackle another.

# %%
df_ba.isna().sum()
# Out:
# brewery_id                0
# brewery_name              0
# review_time               0
# review_overall            0
# review_aroma              0
# review_appearance         0
# review_profilename      348
# beer_style                0
# review_palate             0
# review_taste              0
# beer_name                 0
# beer_abv              67785
# beer_beerid               0
# dtype: int64

# %% [markdown]
# Review_profilename is an interesting column. It's the name of the user who submitted the review and since we don't have a scoring system associated with each user, I'm just going to drop the column and assume that all beers are rated equally and fairly.

# %%
df_ba.drop(['review_profilename'], inplace=True, axis=1)

# Let us check to make sure this was dropped correctly.

# %%
df_ba.isna().sum()

# nice, only beer_abv to deal with
# Out:
# brewery_id               0
# brewery_name             0
# review_time              0
# review_overall           0
# review_aroma             0
# review_appearance        0
# beer_style               0
# review_palate            0
# review_taste             0
# beer_name                0
# beer_abv             67785
# beer_beerid              0
# dtype: int64

# %% [markdown]
# This is a solid chunk of our data. I think the best approach would be to take the mean beer_abv for each beer_style and then apply that to our data. It's not a fool proof approach however it certaily would give us a good indication of the ABV so we can use that data going forward. There certainly will be some outliers here however beer style is a generally good way of designating ABV as different styles have different ABVs.

# %%
beer_styles = list(df_ba['beer_style'].unique())
beer_styles[:5]

# Cool, looks like we have a unique list of different beers.
# Out:
# ['Hefeweizen',
#  'English Strong Ale',
#  'Foreign / Export Stout',
#  'German Pilsener',
#  'American Double / Imperial IPA']

# %%
beer_abv = {}

for style in beer_styles:
        func_df = df_ba[df_ba['beer_style'] == style]
        mean = round(func_df['beer_abv'].mean(),1)
        beer_abv.update({style : mean})

# %%
beer_abv

# want to float these to only 1 decimal, updated function above.
# Out:
# {'Hefeweizen': 5.3,
#  'English Strong Ale': 7.3,
#  'Foreign / Export Stout': 7.7,
#  'German Pilsener': 5.0,
#  'American Double / Imperial IPA': 9.4,
#  'Herbed / Spiced Beer': 6.6,
#  'Light Lager': 4.0,
#  'Oatmeal Stout': 5.8,
#  'American Pale Lager': 5.0,
#  'Rauchbier': 5.7,
#  'American Pale Ale (APA)': 5.5,
#  'American Porter': 6.2,
#  'Belgian Strong Dark Ale': 9.4,
#  'American IPA': 6.6,
#  'American Stout': 6.3,
#  'Russian Imperial Stout': 10.0,
#  'American Amber / Red Ale': 6.0,
#  'American Strong Ale': 9.8,
#  'Märzen / Oktoberfest': 5.9,
#  'American Adjunct Lager': 4.9,
#  'American Blonde Ale': 5.0,
#  'Euro Pale Lager': 5.1,
#  'English Brown Ale': 5.2,
#  'Scotch Ale / Wee Heavy': 8.2,
#  'Fruit / Vegetable Beer': 5.8,
#  'American Double / Imperial Stout': 10.6,
#  'Belgian Pale Ale': 6.1,
#  'English Bitter': 4.3,
#  'English Porter': 5.7,
#  'Irish Dry Stout': 4.9,
#  'American Barleywine': 10.7,
#  'Belgian Strong Pale Ale': 8.7,
#  'Doppelbock': 8.3,
# ...

# %%
beer_abv['Gose']
# Out:
# 4.7

# %%
df_ba.isna().sum()
# Out:
# brewery_id               0
# brewery_name             0
# review_time              0
# review_overall           0
# review_aroma             0
# review_appearance        0
# beer_style               0
# review_palate            0
# review_taste             0
# beer_name                0
# beer_abv             67785
# beer_beerid              0
# dtype: int64

# %%
for beer in beer_abv:
    df_ba['beer_abv'] = df_ba['beer_abv'].fillna(beer_abv[beer])

# %%
print(df_ba.info())
df_ba.isna().sum()

# This dataset is very clean now.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1586614 entries, 0 to 1586613
# Data columns (total 12 columns):
#  #   Column             Non-Null Count    Dtype
# ---  ------             --------------    -----
#  0   brewery_id         1586614 non-null  int64
#  1   brewery_name       1586614 non-null  object
#  2   review_time        1586614 non-null  int64
#  3   review_overall     1586614 non-null  float64
#  4   review_aroma       1586614 non-null  float64
#  5   review_appearance  1586614 non-null  float64
#  6   beer_style         1586614 non-null  object
#  7   review_palate      1586614 non-null  float64
#  8   review_taste       1586614 non-null  float64
#  9   beer_name          1586614 non-null  object
#  10  beer_abv           1586614 non-null  float64
#  11  beer_beerid        1586614 non-null  int64
# dtypes: float64(6), int64(3), object(3)
# memory usage: 145.3+ MB
# None
# brewery_id           0
# brewery_name         0
# review_time          0
# ...
